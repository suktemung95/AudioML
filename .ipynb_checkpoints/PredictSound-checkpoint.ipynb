# %%
from glob import glob
import librosa    
import os

# %%
sounds = glob("./data/*/*.wav")

wf, sr = librosa.load(sounds[0])


def extract_features(y, sr):
    pass
    features = []  

X = []
y = []
for sound in sounds:
    pass
    waveform, sr = librosa.load(sound)
    features = extract_features(waveform, sr)
    label = os.path.dirname(sound)
    X.append(features)
    y.append(label)
